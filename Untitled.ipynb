# %%
import cv2 as cv
from matplotlib import pyplot as plt
import _test_get_cossim as test
from PyQt5 import QtCore, QtWidgets
import sys

# %%
app = QtWidgets.QApplication(sys.argv)
app.aboutToQuit.connect(app.deleteLater)
widget = QtWidgets.QWidget()
widget.resize(960, 540)
widget.setWindowTitle('compare result')
widget.show()
sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
if __name__ == "__main__":
    O_IN = {}
    O_IN['s_img_url_a'] = "./input_1.png"
    O_IN['s_img_url_b'] = "../img_results/input_1/result_1.png"
    test.proc_main(O_IN)
# Out:
# img url: ./input_1.png
# gist feature: [[0.01444858 0.01734405 0.01586657 ... 0.02609513 0.05016385 0.09395234]]
# gist feature(L2 norm): [0.0035677  0.00428266 0.00391783 ... 0.0064435  0.01238664 0.02319905]
#
#
# img url: ../img_results/input_1/result_1.png
# gist feature: [[0.02053091 0.10388581 0.06438442 ... 0.0560923  0.04155891 0.03262165]]
# gist feature(L2 norm): [0.00491463 0.0248679  0.01541217 ... 0.01342722 0.00994826 0.00780888]
#
# 0.73135350937925325265354
